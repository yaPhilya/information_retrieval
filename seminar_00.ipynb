# %%
url = 'https://simple.wikipedia.org/wiki/Main_Page;wtf?unused=True#tram-pam-pam'
print(url)
# Out:
# https://simple.wikipedia.org/wiki/Main_Page;wtf?unused=True#tram-pam-pam

# %%
from urllib.parse import urlparse
from urllib.parse import urldefrag

# %%
print(urlparse(url))
# Out:
# ParseResult(scheme='https', netloc='simple.wikipedia.org', path='/wiki/Main_Page', params='wtf', query='unused=True', fragment='tram-pam-pam')

# %%
urlparse(url).netloc + urlparse(url).path
# Out:
# 'simple.wikipedia.org/wiki/Main_Page'

# %%
print(urldefrag(url).url)
# Out:
# https://simple.wikipedia.org/wiki/Main_Page;wtf?unused=True

# %%
urldefrag(url)
# Out:
# DefragResult(url='https://simple.wikipedia.org/wiki/Main_Page;wtf?unused=True', fragment='tram-pam-pam')

# %%
from urllib.request import urlopen

def download_from_the_internet(url):
    try:
        return urlopen(url).read().decode('utf-8')
    except KeyboardInterrupt:
        raise
    except:
        return None

url = 'https://simple.wikipedia.org/wiki/Main_Page'
html = download_from_the_internet(url)
print(html)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
from file_storage import FileStorage

fs = FileStorage('storage')
fs.write(url, html)
fs.write('test', 'hello')

print(fs.read('test'))
# Out:
# hello

# %%
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def extract_links_from_html(url, html):
    parser = BeautifulSoup(html)
    return [link.get('href') for link in parser.findAll('a')]

links = extract_links_from_html(url, html)
for link in links:
    print(urljoin(url, link))
# Out:
# https://simple.wikipedia.org/wiki/Main_Page;wtf?unused=True#tram-pam-pam
# https://simple.wikipedia.org/wiki/Main_Page;wtf?unused=True#mw-head
# https://simple.wikipedia.org/wiki/Main_Page;wtf?unused=True#p-search
# https://simple.wikipedia.org/wiki/Wikipedia:About
# https://simple.wikipedia.org/wiki/Encyclopedia
# https://simple.wikipedia.org/wiki/Wikipedia:Introduction
# https://simple.wikipedia.org/wiki/Special:Statistics
# https://simple.wikipedia.org/wiki/Simple_English_Wikipedia
# https://simple.wikipedia.org/wiki/Wikipedia:How_to_write_Simple_English_pages
# https://simple.wikipedia.org/wiki/Wikipedia:Useful
# https://simple.wikipedia.org/wiki/Wikipedia:Simple_talk
# https://simple.wikipedia.org/wiki/Special:CategoryTree/Project
# https://simple.wikipedia.org/wiki/Help:Contents
# https://simple.wikipedia.org/wiki/Wikipedia:Schools
# https://simple.wikipedia.org/wiki/Simple_English_Wikipedia
# https://simple.wikipedia.org/wiki/Encyclopedia
# ...
